# %%
# Our user defined plotting functions are in the utils folder. Please navigate there to use.
import sys
sys.path.insert(0, "../../..")
from utils.plot_utils_v2 import plot_trace
from utils.chain_utils import summarize_trace_nc
# Out:
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
#summarize_trace_nc("./../res/vardi_general_chain_reparam_corr.nc")
summarize_trace_nc("./../res/ehux_monod_reparam_mh4.nc")
# Out:
# Loaded trace from: ./../res/ehux_monod_reparam_mh4.nc
# Chains: 3
# Draws per chain: 20000
#
# Parameter: D0
#   Mean: 30845.29783792258
#   Std: 4434.195483989404
#
# Parameter: Ks
#   Mean: 0.3365795087342577
#   Std: 0.11067173024703643
#
# Parameter: N0
#   Mean: 868.2927260907024
#   Std: 100.7464821960946
#
# Parameter: P0
#   Mean: 224011.1198317316
#   Std: 7716.165388774996
#
# Parameter: Qn
#   Mean: 3.16446168239962e-10
#   Std: 3.6993977291979086e-11
#
# Parameter: delta
#   Mean: 0.03427143027627162
#   Std: 0.0022623838859899565
#
# Parameter: mu_max
#   Mean: 0.46424826678771897
#   Std: 0.022066674538899236
#
# Parameter: sigma_dead
#   Mean: 0.2833472724150673
#   Std: 0.059487083067059056
#
# Parameter: sigma_live
#   Mean: 0.1340107246105661
#   Std: 0.028831363528891846
