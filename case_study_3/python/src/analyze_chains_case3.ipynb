# %%
# Our user defined plotting functions are in the utils folder. Please navigate there to use.
import sys
sys.path.insert(0, "../../..")
from utils.plot_utils_v2 import plot_trace
from utils.chain_utils import summarize_trace_nc
# Out:
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
summarize_trace_nc("./../res/vardi_general_chain_reparam_corr.nc")
# Out:
# Loaded trace from: ./../res/vardi_general_chain_reparam_corr.nc
# Chains: 3
# Draws per chain: 20000
#
# Parameter: D0
#   Mean: 32183.76836325932
#   Std: 4405.972719703187
#
# Parameter: Ks
#   Mean: 0.255780091747301
#   Std: 0.09401211067278423
#
# Parameter: N0
#   Mean: 1159.7133837402846
#   Std: 385.3623583791386
#
# Parameter: P0
#   Mean: 181321.99391089124
#   Std: 8634.056251036876
#
# Parameter: Qn
#   Mean: 3.774968181465024e-10
#   Std: 1.3873044901648989e-10
#
# Parameter: delta
#   Mean: 0.032763179289742934
#   Std: 0.002273196423393213
#
# Parameter: mu_max
#   Mean: 0.5114018803747618
#   Std: 0.03387320713829148
#
# Parameter: sigma_dead
#   Mean: 0.2752232319139287
#   Std: 0.058970644748865673
#
# Parameter: sigma_live
#   Mean: 0.17282248839311043
#   Std: 0.04527869348642772
