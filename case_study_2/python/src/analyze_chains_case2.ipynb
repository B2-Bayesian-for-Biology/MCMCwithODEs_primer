# %%
# Our user defined plotting functions are in the utils folder. Please navigate there to use.
import sys
sys.path.insert(0, "../../..")
from utils.plot_utils_v2 import plot_trace
from utils.chain_utils import summarize_trace_nc
# Out:
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
summarize_trace_nc("./../res/vardi_logistic_growth_chain_corrected.nc")
# Out:
# Loaded trace from: ./../res/vardi_logistic_growth_chain_corrected.nc
# Chains: 3
# Draws per chain: 2000
#
# Parameter: $K$ (carrying capacity)
#   Mean: 3209164.0716800685
#   Std: 99814.29246915005
#
# Parameter: $P_0$ (init. live)
#   Mean: 236329.28979300737
#   Std: 17916.926828056454
#
# Parameter: $\sigma_L$
#   Mean: 0.08962407045710176
#   Std: 0.020053278233979042
#
# Parameter: $r$ (growth rate)
#   Mean: 0.5881879872027082
#   Std: 0.03633359418650033

# %%
summarize_trace_nc("./../res/vardi_logistic_growth_death_chain_seq.nc")
# Out:
# Loaded trace from: ./../res/vardi_logistic_growth_death_chain_seq.nc
# Chains: 3
# Draws per chain: 2000
#
# Parameter: $D_0$ (init. dead)
#   Mean: 31104.705278529345
#   Std: 5760.84467787558
#
# Parameter: $K$ (carrying capacity)
#   Mean: 3080329.3911491106
#   Std: 104356.95945213965
#
# Parameter: $P_0$ (init. live)
#   Mean: 211017.78020005414
#   Std: 14379.644741839513
#
# Parameter: $\delta$ (death rate)
#   Mean: 0.03362623980855304
#   Std: 0.003239383582233035
#
# Parameter: $\sigma_D$
#   Mean: 0.2272859139951938
#   Std: 0.0578629912929827
#
# Parameter: $\sigma_L$
#   Mean: 0.15823199965080922
#   Std: 0.040788929533869804
#
# Parameter: $r$ (growth rate)
#   Mean: 0.5833909590213118
#   Std: 0.029616185177726715
