# %%
# Our user defined plotting functions are in the utils folder. Please navigate there to use.
import sys
sys.path.insert(0, "../../..")
from utils.plot_utils_v2 import plot_trace
from utils.chain_utils import summarize_trace_nc
# Out:
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
summarize_trace_nc("./../data/normal_growth_trace.nc")
# Out:
# Loaded trace from: ./../data/normal_growth_trace.nc
# Chains: 4
# Draws per chain: 1000
#
# Parameter: mum
#   Mean: 0.2807088555764583
#   Std: 0.04332389175875704
#
# Parameter: N0
#   Mean: 1549191.1093058628
#   Std: 84262.96082165158
#
# Parameter: sigma
#   Mean: 0.13686380633310938
#   Std: 0.031366769062422264

# %%
summarize_trace_nc("./../data/normal_death_trace.nc")
# Out:
# Loaded trace from: ./../data/normal_death_trace.nc
# Chains: 4
# Draws per chain: 2000
#
# Parameter: N0
#   Mean: 1564243.4900981463
#   Std: 86543.1343642119
#
# Parameter: delta
#   Mean: 0.38360141349691834
#   Std: 0.15364611548525714
#
# Parameter: mum
#   Mean: 0.6547672395581048
#   Std: 0.15472716406843492
#
# Parameter: sigma
#   Mean: 0.13689402867130565
#   Std: 0.03214177545158941
